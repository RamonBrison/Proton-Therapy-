# %% [markdown]
# ### Useful Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Simulation Data

# %%
energies = [70, 100, 125, 150, 175, 200, 225, 250]
r80_simulated = [3.59, 7.25, 11.02, 15.37, 20.24, 25.60, 31.41, 37.66]
penumbra      = [0.06, 0.13, 0.18,  0.23,  0.29,  0.36,  0.43,  0.51]
csda_nist     = [4.08, 7.718, 11.46, 15.77, 20.62, 25.96, 31.74, 37.94]
deviations = []

for r80 in r80_simulated and r_nist in csda_nist:
    deviation = abs(r_nist - r80)/r_nist * 100
    deviations.append(deviation)
